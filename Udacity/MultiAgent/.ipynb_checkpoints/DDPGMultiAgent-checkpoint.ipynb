# %% [markdown]
# # Deep Deterministic Policy Gradients (DDPG)
# ---
# In this notebook, we train DDPG with OpenAI Gym's Pendulum-v0 environment.
#
# ### 1. Import the Necessary Packages

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

from unityagents import UnityEnvironment

import pdb

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
path = 'C:\\Users\\mbgpcsk4\\Dropbox (The University of Manchester)\\D2019\\University\\Udacity\\P2_Reacher_Submission\\Udacity\\MultiAgent\\Reacher_Windows_x86_64\\Reacher.exe'

env = UnityEnvironment(file_name=path)

# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

agent = Agent(state_size=33, action_size=4, random_seed=2)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
agent.reset()
agent.print_params()
# Out:
# --Return--
# > <ipython-input-7-f7f3a85564f6>(2)<module>()->None
# -> pdb.set_trace()
# ERROR! Session/line number was not unique in database. History logging moved to new session 302
# (Pdb)
# (Pdb) n
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3328)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3344)run_code()
# -> outflag = False
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3345)run_code()
# -> return outflag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3345)run_code()->False
# -> return outflag
# (Pdb)
# Internal StopIteration: False
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3248)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3240)run_ast_nodes()
# -> for node,mode in to_run:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3241)run_ast_nodes()
# -> if mode == 'exec':
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3242)run_ast_nodes()
# -> mod = Module([node], [])
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(117)<lambda>()
# -> Module = lambda nodelist, type_ignores: OriginalModule(nodelist)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(117)<lambda>()
# -> Module = lambda nodelist, type_ignores: OriginalModule(nodelist)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(117)<lambda>()-><_ast.Module ...002434E271C50>
# -> Module = lambda nodelist, type_ignores: OriginalModule(nodelist)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3245)run_ast_nodes()
# -> with compiler.extra_flags(getattr(ast, 'PyCF_ALLOW_TOP_LEVEL_AWAIT', 0x0) if self.autoawait else 0x0):
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(545)__get__()
# -> def __get__(self, obj, cls=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(553)__get__()
# -> if obj is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(556)__get__()
# -> return self.get(obj, cls)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(526)get()
# -> def get(self, obj, cls=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(527)get()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(528)get()
# -> value = obj._trait_values[self.name]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(543)get()
# -> return value
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(543)get()->True
# -> return value
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(556)__get__()->True
# -> return self.get(obj, cls)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(157)helper()
# -> @wraps(func)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(159)helper()
# -> return _GeneratorContextManager(func, args, kwds)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(59)__init__()
# -> def __init__(self, func, args, kwds):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(60)__init__()
# -> self.gen = func(*args, **kwds)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(61)__init__()
# -> self.func, self.args, self.kwds = func, args, kwds
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(63)__init__()
# -> doc = getattr(func, "__doc__", None)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(64)__init__()
# -> if doc is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(65)__init__()
# -> doc = type(self).__doc__
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(66)__init__()
# -> self.__doc__ = doc
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(66)__init__()->None
# -> self.__doc__ = doc
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(159)helper()-><contextlib._...0024365FFDE48>
# -> return _GeneratorContextManager(func, args, kwds)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(79)__enter__()
# -> def __enter__(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(80)__enter__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(81)__enter__()
# -> return next(self.gen)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(138)extra_flags()
# -> @contextmanager
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(141)extra_flags()
# -> turn_on_bits = ~self.flags & flags
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(144)extra_flags()
# -> self.flags = self.flags | flags
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(145)extra_flags()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()
# -> yield
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()->None
# -> yield
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(81)__enter__()->None
# -> return next(self.gen)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3246)run_ast_nodes()
# -> code = compiler(mod, cell_name, mode)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\codeop.py(132)__call__()
# -> def __call__(self, source, filename, symbol):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(133)__call__()
# -> codeob = compile(source, filename, symbol, self.flags, 1)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(137)__call__()
# -> return codeob
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\codeop.py(137)__call__()-><code object ...4f6>", line 3>
# -> return codeob
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3247)run_ast_nodes()
# -> asy = compare(code)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3229)compare()
# -> def compare(code):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3230)compare()
# -> return _async
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3230)compare()->False
# -> return _async
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(85)__exit__()
# -> def __exit__(self, type, value, traceback):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(86)__exit__()
# -> if type is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(87)__exit__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(88)__exit__()
# -> next(self.gen)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()->None
# -> yield
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(150)extra_flags()->None
# -> self.flags &= ~turn_on_bits
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(150)extra_flags()->None
# -> self.flags &= ~turn_on_bits
# (Pdb)
# StopIteration
# > c:\anaconda3\envs\p1\lib\contextlib.py(88)__exit__()
# -> next(self.gen)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(89)__exit__()
# -> except StopIteration:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(90)__exit__()
# -> return False
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(90)__exit__()->False
# -> return False
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3248)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3287)run_code()
# -> async def run_code(self, code_obj, result=None, *, async_=False):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3309)run_code()
# -> old_excepthook, sys.excepthook = sys.excepthook, self.excepthook
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3313)run_code()
# -> self.sys_excepthook = old_excepthook
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3314)run_code()
# -> outflag = True  # happens in more places, so it's easier as default
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3315)run_code()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3316)run_code()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3317)run_code()
# -> self.hooks.pre_run_code_hook()
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(125)__getattr__()
# -> def __getattr__(self, key):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(146)__getattr__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(147)__getattr__()
# -> result = self[key]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(151)__getattr__()
# -> return result
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(151)__getattr__()-><IPython.core...002434E1807F0>
# -> return result
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(142)__call__()
# -> def __call__(self,*args, **kw):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(148)__call__()
# -> last_exc = TryNext()
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(149)__call__()
# -> for prio,cmd in self.chain:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(151)__call__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(152)__call__()
# -> return cmd(*args, **kw)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(207)pre_run_code_hook()
# -> def pre_run_code_hook(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(209)pre_run_code_hook()
# -> return None
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(209)pre_run_code_hook()->None
# -> return None
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(152)__call__()->None
# -> return cmd(*args, **kw)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3318)run_code()
# -> if async_ and sys.version_info < (3,8):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3322)run_code()
# -> elif async_ :
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3325)run_code()
# -> exec(code_obj, self.user_global_ns, self.user_ns)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1272)user_global_ns()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1274)user_global_ns()
# -> return self.user_module.__dict__
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1274)user_global_ns()->{'Agent': <class 'ddpg_agent.Agent'>, 'In': ['', "def ddpg(n_e...)\nplt.show()", 'import gym\n...n\nimport pdb', "path = 'C:\\...andom_seed=2)", "def ddpg(n_e...)\nplt.show()", "def ddpg(n_e...)\nplt.show()", ...], 'Out': {}, 'UnityEnvironment': <class 'unity...yEnvironment'>, ...}
# -> return self.user_module.__dict__
# (Pdb)
# --Call--
# > <ipython-input-7-f7f3a85564f6>(3)<module>()->None
# -> agent.reset()
# (Pdb)
# > <ipython-input-7-f7f3a85564f6>(3)<module>()->None
# -> agent.reset()
# (Pdb) s
# --Call--
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(87)reset()
# -> def reset(self):
# (Pdb)
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(88)reset()
# -> self.noise.reset()
# (Pdb) s
# --Call--
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(171)reset()
# -> def reset(self):
# (Pdb)
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(173)reset()
# -> self.state = copy.copy(self.mu)
# (Pdb) self.mu
# array([0., 0., 0., 0.])
# (Pdb)
# array([0., 0., 0., 0.])
# (Pdb) s
# --Call--
# > c:\anaconda3\envs\p1\lib\copy.py(66)copy()
# -> def copy(x):
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\copy.py(72)copy()
# -> cls = type(x)
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\copy.py(74)copy()
# -> copier = _copy_dispatch.get(cls)
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\copy.py(75)copy()
# -> if copier:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(78)copy()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(79)copy()
# -> issc = issubclass(cls, type)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(82)copy()
# -> if issc:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(86)copy()
# -> copier = getattr(cls, "__copy__", None)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(87)copy()
# -> if copier:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\copy.py(88)copy()
# -> return copier(x)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\copy.py(88)copy()->array([0., 0., 0., 0.])
# -> return copier(x)
# (Pdb)
# --Return--
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(173)reset()->None
# -> self.state = copy.copy(self.mu)
# (Pdb)
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(89)reset()
# -> self.actor_local.reset_parameters
# (Pdb) s
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(90)reset()
# -> self.actor_target.reset_parameters
# (Pdb)
# --Return--
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(90)reset()->None
# -> self.actor_target.reset_parameters
# (Pdb)
# --Return--
# > <ipython-input-7-f7f3a85564f6>(3)<module>()->None
# -> agent.reset()
# (Pdb) s
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3328)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3344)run_code()
# -> outflag = False
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3345)run_code()
# -> return outflag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3345)run_code()->False
# -> return outflag
# (Pdb)
# Internal StopIteration: False
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3248)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3240)run_ast_nodes()
# -> for node,mode in to_run:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3241)run_ast_nodes()
# -> if mode == 'exec':
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3243)run_ast_nodes()
# -> elif mode == 'single':
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3244)run_ast_nodes()
# -> mod = ast.Interactive([node])
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3245)run_ast_nodes()
# -> with compiler.extra_flags(getattr(ast, 'PyCF_ALLOW_TOP_LEVEL_AWAIT', 0x0) if self.autoawait else 0x0):
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(545)__get__()
# -> def __get__(self, obj, cls=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(553)__get__()
# -> if obj is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(556)__get__()
# -> return self.get(obj, cls)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(526)get()
# -> def get(self, obj, cls=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(527)get()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(528)get()
# -> value = obj._trait_values[self.name]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(543)get()
# -> return value
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(543)get()->True
# -> return value
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\traitlets\traitlets.py(556)__get__()->True
# -> return self.get(obj, cls)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(157)helper()
# -> @wraps(func)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(159)helper()
# -> return _GeneratorContextManager(func, args, kwds)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(59)__init__()
# -> def __init__(self, func, args, kwds):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(60)__init__()
# -> self.gen = func(*args, **kwds)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(61)__init__()
# -> self.func, self.args, self.kwds = func, args, kwds
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(63)__init__()
# -> doc = getattr(func, "__doc__", None)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(64)__init__()
# -> if doc is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(65)__init__()
# -> doc = type(self).__doc__
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(66)__init__()
# -> self.__doc__ = doc
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(66)__init__()->None
# -> self.__doc__ = doc
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(159)helper()-><contextlib._...002434E271C50>
# -> return _GeneratorContextManager(func, args, kwds)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(79)__enter__()
# -> def __enter__(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(80)__enter__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(81)__enter__()
# -> return next(self.gen)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(138)extra_flags()
# -> @contextmanager
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(141)extra_flags()
# -> turn_on_bits = ~self.flags & flags
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(144)extra_flags()
# -> self.flags = self.flags | flags
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(145)extra_flags()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()
# -> yield
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()->None
# -> yield
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(81)__enter__()->None
# -> return next(self.gen)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3246)run_ast_nodes()
# -> code = compiler(mod, cell_name, mode)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\codeop.py(132)__call__()
# -> def __call__(self, source, filename, symbol):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(133)__call__()
# -> codeob = compile(source, filename, symbol, self.flags, 1)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(135)__call__()
# -> if codeob.co_flags & feature.compiler_flag:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(134)__call__()
# -> for feature in _features:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\codeop.py(137)__call__()
# -> return codeob
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\codeop.py(137)__call__()-><code object ...4f6>", line 4>
# -> return codeob
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3247)run_ast_nodes()
# -> asy = compare(code)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3229)compare()
# -> def compare(code):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3230)compare()
# -> return _async
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3230)compare()->False
# -> return _async
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\contextlib.py(85)__exit__()
# -> def __exit__(self, type, value, traceback):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(86)__exit__()
# -> if type is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(87)__exit__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(88)__exit__()
# -> next(self.gen)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(146)extra_flags()->None
# -> yield
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(150)extra_flags()->None
# -> self.flags &= ~turn_on_bits
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\compilerop.py(150)extra_flags()->None
# -> self.flags &= ~turn_on_bits
# (Pdb)
# StopIteration
# > c:\anaconda3\envs\p1\lib\contextlib.py(88)__exit__()
# -> next(self.gen)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(89)__exit__()
# -> except StopIteration:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\contextlib.py(90)__exit__()
# -> return False
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\contextlib.py(90)__exit__()->False
# -> return False
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3248)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3287)run_code()
# -> async def run_code(self, code_obj, result=None, *, async_=False):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3309)run_code()
# -> old_excepthook, sys.excepthook = sys.excepthook, self.excepthook
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3313)run_code()
# -> self.sys_excepthook = old_excepthook
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3314)run_code()
# -> outflag = True  # happens in more places, so it's easier as default
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3315)run_code()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3316)run_code()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3317)run_code()
# -> self.hooks.pre_run_code_hook()
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(125)__getattr__()
# -> def __getattr__(self, key):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(146)__getattr__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(147)__getattr__()
# -> result = self[key]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(151)__getattr__()
# -> return result
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\utils\ipstruct.py(151)__getattr__()-><IPython.core...002434E1807F0>
# -> return result
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(142)__call__()
# -> def __call__(self,*args, **kw):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(148)__call__()
# -> last_exc = TryNext()
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(149)__call__()
# -> for prio,cmd in self.chain:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(151)__call__()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(152)__call__()
# -> return cmd(*args, **kw)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(207)pre_run_code_hook()
# -> def pre_run_code_hook(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(209)pre_run_code_hook()
# -> return None
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(209)pre_run_code_hook()->None
# -> return None
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\hooks.py(152)__call__()->None
# -> return cmd(*args, **kw)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3318)run_code()
# -> if async_ and sys.version_info < (3,8):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3322)run_code()
# -> elif async_ :
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(3325)run_code()
# -> exec(code_obj, self.user_global_ns, self.user_ns)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1272)user_global_ns()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1274)user_global_ns()
# -> return self.user_module.__dict__
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipython\core\interactiveshell.py(1274)user_global_ns()->{'Agent': <class 'ddpg_agent.Agent'>, 'In': ['', "def ddpg(n_e...)\nplt.show()", 'import gym\n...n\nimport pdb', "path = 'C:\\...andom_seed=2)", "def ddpg(n_e...)\nplt.show()", "def ddpg(n_e...)\nplt.show()", ...], 'Out': {}, 'UnityEnvironment': <class 'unity...yEnvironment'>, ...}
# -> return self.user_module.__dict__
# (Pdb)
# --Call--
# > <ipython-input-7-f7f3a85564f6>(4)<module>()->None
# -> agent.print_params()
# (Pdb)
# > <ipython-input-7-f7f3a85564f6>(4)<module>()->None
# -> agent.print_params()
# (Pdb)
# --Call--
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(92)print_params()
# -> def print_params(self):
# (Pdb)
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(93)print_params()
# -> print("Actor:\n")
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(382)write()
# -> def write(self, string):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(383)write()
# -> if self.echo is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(391)write()
# -> if self.pub_thread is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(395)write()
# -> if not isinstance(string, unicode_type):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(398)write()
# -> is_child = (not self._is_master_process())
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(307)_is_master_process()
# -> def _is_master_process(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(308)_is_master_process()
# -> return os.getpid() == self._master_pid
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(308)_is_master_process()->True
# -> return os.getpid() == self._master_pid
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(400)write()
# -> self.pub_thread.schedule(lambda : self._buffer.write(string))
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1104)is_alive()
# -> def is_alive(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1112)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1113)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(506)is_set()
# -> def is_set(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()
# -> return self._flag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()->True
# -> return self._flag
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1115)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1062)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1069)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1070)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()
# -> return not self._is_stopped
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()->True
# -> return not self._is_stopped
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(201)schedule()
# -> self._events.append(f)
# (Pdb)
# Actor:
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()
# -> self._event_pipe.send(b'')
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(93)_event_pipe()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(96)_event_pipe()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(97)_event_pipe()
# -> event_pipe = self._local.event_pipe
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()
# -> return event_pipe
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()-><zmq.sugar.so...002434E26E1E8>
# -> return event_pipe
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(337)send()
# -> def send(self, data, flags=0, copy=True, track=False, routing_id=None, group=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(385)send()
# -> if routing_id is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(390)send()
# -> if group is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()->None
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()->None
# -> self._event_pipe.send(b'')
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(401)write()
# -> if is_child:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(408)write()
# -> self._schedule_flush()
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(320)_schedule_flush()
# -> def _schedule_flush(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(325)_schedule_flush()
# -> if self._flush_pending:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(327)_schedule_flush()
# -> self._flush_pending = True
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(330)_schedule_flush()
# -> def _schedule_in_thread():
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(332)_schedule_flush()
# -> self.pub_thread.schedule(_schedule_in_thread)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1104)is_alive()
# -> def is_alive(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1112)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1113)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(506)is_set()
# -> def is_set(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()
# -> return self._flag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()->True
# -> return self._flag
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1115)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1062)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1069)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1070)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()
# -> return not self._is_stopped
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()->True
# -> return not self._is_stopped
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(201)schedule()
# -> self._events.append(f)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()
# -> self._event_pipe.send(b'')
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(93)_event_pipe()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(96)_event_pipe()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(97)_event_pipe()
# -> event_pipe = self._local.event_pipe
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()
# -> return event_pipe
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()-><zmq.sugar.so...002434E26E1E8>
# -> return event_pipe
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(337)send()
# -> def send(self, data, flags=0, copy=True, track=False, routing_id=None, group=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(385)send()
# -> if routing_id is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(390)send()
# -> if group is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()->None
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()->None
# -> self._event_pipe.send(b'')
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(332)_schedule_flush()->None
# -> self.pub_thread.schedule(_schedule_in_thread)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(408)write()->None
# -> self._schedule_flush()
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(382)write()
# -> def write(self, string):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(383)write()
# -> if self.echo is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(391)write()
# -> if self.pub_thread is None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(395)write()
# -> if not isinstance(string, unicode_type):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(398)write()
# -> is_child = (not self._is_master_process())
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(307)_is_master_process()
# -> def _is_master_process(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(308)_is_master_process()
# -> return os.getpid() == self._master_pid
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(308)_is_master_process()->True
# -> return os.getpid() == self._master_pid
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(400)write()
# -> self.pub_thread.schedule(lambda : self._buffer.write(string))
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1104)is_alive()
# -> def is_alive(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1112)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1113)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(506)is_set()
# -> def is_set(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()
# -> return self._flag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()->True
# -> return self._flag
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1115)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1062)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1069)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1070)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()
# -> return not self._is_stopped
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()->True
# -> return not self._is_stopped
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(201)schedule()
# -> self._events.append(f)
# (Pdb)
#
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()
# -> self._event_pipe.send(b'')
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(93)_event_pipe()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(96)_event_pipe()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(97)_event_pipe()
# -> event_pipe = self._local.event_pipe
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()
# -> return event_pipe
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()-><zmq.sugar.so...002434E26E1E8>
# -> return event_pipe
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(337)send()
# -> def send(self, data, flags=0, copy=True, track=False, routing_id=None, group=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(385)send()
# -> if routing_id is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(390)send()
# -> if group is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()->None
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()->None
# -> self._event_pipe.send(b'')
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(401)write()
# -> if is_child:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(408)write()
# -> self._schedule_flush()
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(320)_schedule_flush()
# -> def _schedule_flush(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(325)_schedule_flush()
# -> if self._flush_pending:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(327)_schedule_flush()
# -> self._flush_pending = True
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(330)_schedule_flush()
# -> def _schedule_in_thread():
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(332)_schedule_flush()
# -> self.pub_thread.schedule(_schedule_in_thread)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(195)schedule()
# -> def schedule(self, f):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(200)schedule()
# -> if self.thread.is_alive():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1104)is_alive()
# -> def is_alive(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1112)is_alive()
# -> assert self._initialized, "Thread.__init__() not called"
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1113)is_alive()
# -> if self._is_stopped or not self._started.is_set():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(506)is_set()
# -> def is_set(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()
# -> return self._flag
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(508)is_set()->True
# -> return self._flag
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1115)is_alive()
# -> self._wait_for_tstate_lock(False)
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\threading.py(1062)_wait_for_tstate_lock()
# -> def _wait_for_tstate_lock(self, block=True, timeout=-1):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1069)_wait_for_tstate_lock()
# -> lock = self._tstate_lock
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1070)_wait_for_tstate_lock()
# -> if lock is None:  # already determined that the C code is done
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()
# -> elif lock.acquire(block, timeout):
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1072)_wait_for_tstate_lock()->None
# -> elif lock.acquire(block, timeout):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()
# -> return not self._is_stopped
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\threading.py(1116)is_alive()->True
# -> return not self._is_stopped
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(201)schedule()
# -> self._events.append(f)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()
# -> self._event_pipe.send(b'')
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(93)_event_pipe()
# -> @property
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(96)_event_pipe()
# -> try:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(97)_event_pipe()
# -> event_pipe = self._local.event_pipe
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()
# -> return event_pipe
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(105)_event_pipe()-><zmq.sugar.so...002434E26E1E8>
# -> return event_pipe
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(337)send()
# -> def send(self, data, flags=0, copy=True, track=False, routing_id=None, group=None):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(385)send()
# -> if routing_id is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(390)send()
# -> if group is not None:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\zmq\sugar\socket.py(395)send()->None
# -> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(203)schedule()->None
# -> self._event_pipe.send(b'')
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(332)_schedule_flush()->None
# -> self.pub_thread.schedule(_schedule_in_thread)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\ipykernel\iostream.py(408)write()->None
# -> self._schedule_flush()
# (Pdb)
# > c:\users\mbgpcsk4\dropbox (the university of manchester)\d2019\university\udacity\p2_reacher_submission\udacity\multiagent\ddpg_agent.py(94)print_params()
# -> for p in self.actor_target.parameters():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\nn\modules\module.py(723)parameters()
# -> def parameters(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\nn\modules\module.py(739)parameters()
# -> for name, param in self.named_parameters():
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\nn\modules\module.py(742)named_parameters()
# -> def named_parameters(self, memo=None, prefix=''):
# ...
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(153)_vector_str()
# -> element_length = sz + 3
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(154)_vector_str()
# -> elements_per_line = int(math.floor((PRINT_OPTS.linewidth - indent) / (element_length)))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(155)_vector_str()
# -> char_per_line = element_length * elements_per_line
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(157)_vector_str()
# -> if summarize and self.size(0) > 2 * PRINT_OPTS.edgeitems:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(159)_vector_str()
# -> [' ...'] +
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(352)__iter__()
# -> def __iter__(self):
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(359)__iter__()
# -> if self.dim() == 0:
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)__iter__()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)__iter__()-><map object a...0024304961B38>
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()->tensor(1.0000...vice='cuda:0')
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()->tensor(1.0000...vice='cuda:0')
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# --Call--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\tensor.py(361)<lambda>()->tensor(1.0000...vice='cuda:0')
# -> return iter(imap(lambda i: self[i], range(self.size(0))))
# (Pdb) n
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(158)<listcomp>()->[' 9.2155e-02', '-7.6085e-02', '-5.3106e-02']
# -> data = ([fmt.format(val.item() / scale) for val in self[:PRINT_OPTS.edgeitems]] +
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(160)_vector_str()
# -> [fmt.format(val.item() / scale) for val in self[-PRINT_OPTS.edgeitems:]])
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(164)_vector_str()
# -> data_lines = [data[i:i + elements_per_line] for i in range(0, len(data), elements_per_line)]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(165)_vector_str()
# -> lines = [', '.join(line) for line in data_lines]
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(166)_vector_str()
# -> return '[' + (',' + '\n' + ' ' * (indent + 1)).join(lines) + ']'
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(166)_vector_str()->'[ 9.2155e-02...  4.1120e-02]'
# -> return '[' + (',' + '\n' + ' ' * (indent + 1)).join(lines) + ']'
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(175)_tensor_str()->'[ 9.2155e-02...  4.1120e-02]'
# -> return _vector_str(self, indent, fmt, scale, sz, summarize)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(178)<listcomp>()
# -> slices = ([_tensor_str(self[i], indent + 1, fmt, scale, sz, summarize)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(178)<listcomp>()
# -> slices = ([_tensor_str(self[i], indent + 1, fmt, scale, sz, summarize)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(178)<listcomp>()
# -> slices = ([_tensor_str(self[i], indent + 1, fmt, scale, sz, summarize)
# (Pdb)
# --Return--
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(178)<listcomp>()->['[ 9.2155e-02...  4.1120e-02]', '[-7.8745e-02... -2.7500e-02]', '[ 6.7949e-02... -3.5990e-02]']
# -> slices = ([_tensor_str(self[i], indent + 1, fmt, scale, sz, summarize)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(181)_tensor_str()
# -> [_tensor_str(self[i], indent + 1, fmt, scale, sz, summarize)
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(182)_tensor_str()
# -> for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
# (Pdb)
# > c:\anaconda3\envs\p1\lib\site-packages\torch\_tensor_str.py(186)_tensor_str()
# -> tensor_str = (',' + '\n' * (dim - 1) + ' ' * (indent + 1)).join(slices)
# (Pdb) c
# tensor([[ 9.2155e-02, -7.6085e-02, -5.3106e-02,  ...,  1.0541e-01,
#          -8.6647e-03,  4.1120e-02],
#         [-7.8745e-02, -9.2152e-02, -1.1322e-02,  ...,  8.8266e-02,
#          -6.5726e-02, -2.7500e-02],
#         [ 6.7949e-02, -5.5939e-02,  2.3043e-02,  ..., -5.3999e-02,
#           1.6827e-02, -3.5990e-02],
#         ...,
#         [-1.8519e-02, -3.3362e-02, -7.8703e-04,  ...,  8.1158e-02,
#          -1.0475e-02,  2.1764e-02],
#         [ 7.6591e-02,  7.3548e-02, -1.7828e-02,  ..., -5.0867e-02,
#          -1.8678e-02, -7.8163e-02],
#         [-2.4366e-02, -7.9413e-02,  4.5193e-02,  ..., -1.0559e-02,
#           4.4824e-02,  8.8948e-02]], device='cuda:0')
# None tensor([-0.0655,  0.0033, -0.1429,  0.0222, -0.1456, -0.1229,  0.1098,
#         -0.0330, -0.0537, -0.0128, -0.1484,  0.1780,  0.0105, -0.0065,
#         -0.0558,  0.1075, -0.1203,  0.0846, -0.1078, -0.0525, -0.0885,
#         -0.0912, -0.0060, -0.1092, -0.0989, -0.1790,  0.0622, -0.1174,
#         -0.0004, -0.0245, -0.1212, -0.0993,  0.0029,  0.1369, -0.0351,
#          0.1649,  0.0768, -0.1104,  0.0703, -0.1734, -0.0829,  0.1874,
#          0.1852, -0.0819,  0.0351, -0.1546, -0.0748,  0.0348, -0.1422,
#         -0.0420, -0.0866, -0.1124,  0.1108, -0.1218,  0.1565,  0.0521,
#          0.0725, -0.1092,  0.0253,  0.1772, -0.0764, -0.0604, -0.0489,
#         -0.0196,  0.1194,  0.1057, -0.0429,  0.1393, -0.1414, -0.0349,
#         -0.0106,  0.0077,  0.0056,  0.0711,  0.0775, -0.1322,  0.0905,
#          0.0343,  0.1301, -0.0251, -0.1510,  0.0630, -0.0526, -0.1044,
#         -0.0145,  0.1553, -0.1255, -0.0508, -0.1587, -0.0106,  0.0641,
#          0.1052, -0.0355,  0.1461,  0.0948,  0.1202, -0.1002,  0.1349,
#         -0.0274,  0.1480,  0.1365, -0.1365,  0.0375,  0.0348, -0.0139,
#          0.1385,  0.0828, -0.1529,  0.1420,  0.0584,  0.0722,  0.0514,
#          0.0305, -0.0726,  0.0478,  0.0198,  0.0858, -0.0358,  0.1465,
#          0.0128, -0.0144, -0.0471,  0.1754,  0.0080, -0.0484, -0.0583,
#          0.1746, -0.1383], device='cuda:0')
# None tensor([[-0.0394,  0.0579, -0.1037,  ...,  0.0416,  0.1349,  0.0463],
#         [ 0.0867,  0.0527, -0.0328,  ..., -0.0092, -0.1016,  0.0306],
#         [ 0.0492,  0.0037, -0.0033,  ..., -0.0762,  0.1250,  0.0164],
#         ...,
#         [-0.0035, -0.1005, -0.0305,  ...,  0.1201, -0.0899, -0.0340],
#         [ 0.0386, -0.0653, -0.0143,  ...,  0.0628,  0.0083,  0.1273],
#         [-0.0216,  0.1160,  0.0052,  ..., -0.0208,  0.0209,  0.0909]], device='cuda:0')
# None tensor([ 0.0944,  0.0367,  0.0960, -0.0307,  0.0088,  0.0462,  0.0685,
#          0.0156,  0.0565,  0.0333,  0.0891, -0.0593, -0.0430,  0.1002,
#          0.0280, -0.0242, -0.0455,  0.1009, -0.0488, -0.0454,  0.0346,
#          0.0563,  0.0505, -0.0673,  0.1019, -0.0250,  0.0875,  0.0288,
#          0.0985,  0.0273,  0.0698,  0.0043, -0.0116,  0.0919, -0.0634,
#          0.0925, -0.0561,  0.0816,  0.0544,  0.0079,  0.0648,  0.0898,
#         -0.0535,  0.0392, -0.0320,  0.0769, -0.0098,  0.0632,  0.0252,
#          0.0761, -0.0325,  0.0330,  0.0294,  0.0127, -0.0213,  0.0577,
#          0.0406,  0.0156, -0.0156, -0.0207,  0.0202,  0.0833,  0.0671,
#          0.0449], device='cuda:0')
# None tensor(1.00000e-02 *
#        [[ 1.1825,  0.9877,  0.9899,  1.3294,  1.4869,  0.7417,  0.3085,
#           0.9623,  0.6097,  0.5653,  0.8869,  1.3304,  1.0887,  1.0224,
#           1.2262,  1.4378,  1.4550,  0.9379,  0.9427,  0.6474,  0.6800,
#           1.5746,  1.2226,  0.7543,  0.9961,  0.7120,  1.1089,  1.1622,
#           1.2079,  0.9570,  0.8634,  0.6765,  1.4897,  1.2031,  0.9144,
#          -0.5107,  1.2038,  1.6468,  0.7890,  0.7692,  1.5109,  0.3260,
#           0.2243,  0.2719,  0.9994,  1.2695,  0.8445,  0.7497,  1.0157,
#           0.8967,  0.4842,  1.2821,  0.8713,  1.1800, -0.8666,  0.7845,
#           1.7843,  1.2920,  1.1571,  1.2609,  1.1381,  1.2117,  1.5903,
#           0.9903],
#         [ 1.1275,  1.2758,  1.5828,  1.3899,  1.5667,  1.4956,  1.3403,
#           1.5242,  0.9939,  1.5115,  1.4693,  1.4392,  1.1098,  1.3649,
#           1.6962,  1.3175,  1.5373,  0.9539,  1.5717,  1.4685,  1.3337,
#           1.8446,  1.3951,  1.0891,  1.3242,  1.9052,  1.0266,  1.3651,
#           1.3800,  2.3882,  1.4562,  1.5106,  1.7373,  1.3910,  1.8112,
#           1.6090,  1.4363,  1.1065,  1.6302,  1.5640,  1.6395,  1.0623,
#           1.3537,  1.5787,  1.4649,  1.2050,  1.7548,  1.1418,  1.3493,
#           1.0308,  0.7866,  1.2899,  1.3406,  1.4053,  2.2502,  1.4723,
#           1.3312,  1.0266,  1.7818,  1.4454,  1.0271,  1.6341,  1.0975,
#           1.5183],
#         [-1.3695, -0.9874, -1.1398, -1.2970, -1.8883, -1.0159, -1.5261,
#          -1.1455, -0.8453, -1.2392, -0.8656, -1.4815, -1.0617, -1.4875,
#          -1.5821, -1.3956, -1.8591, -0.9775, -1.8973, -1.8421, -1.2107,
#          -1.6177, -1.4213, -1.5604, -1.4412, -1.9727, -1.1358, -1.0945,
#          -1.2365, -2.0282, -1.3521, -1.8257, -1.6038, -1.2367, -1.7844,
#          -1.9958, -1.6924, -1.6243, -1.2787, -1.0912, -1.7847, -1.6573,
#          -1.2822, -1.8437, -1.1425, -1.2922, -1.4926, -1.1505, -1.3759,
#          -1.0500, -1.1031, -1.0893, -1.5264, -1.2156, -1.9342, -1.3325,
#          -1.2145, -1.2513, -1.2680, -1.3963, -1.6238, -1.8744, -1.7398,
#          -1.8064],
#         [ 1.0530,  1.6867,  1.4088,  1.3427,  1.5805,  0.9125,  1.1749,
#           1.7422,  1.3872,  1.7305,  1.2978,  1.0491,  1.4297,  1.3183,
#           1.4461,  1.6686,  1.2254,  1.3117,  1.5873,  1.4498,  1.5693,
#           2.0276,  1.2104,  1.2300,  1.7743,  1.3607,  0.8650,  1.4032,
#           1.0589,  1.1651,  1.3392,  1.3066,  1.6631,  1.4480,  1.3286,
#           0.8116,  1.7271,  1.5807,  1.4971,  1.3508,  1.9218,  1.2229,
#           0.6839,  1.1100,  1.3699,  1.3895,  1.6777,  0.9248,  1.7134,
#           0.8344,  0.9196,  1.5348,  1.4928,  1.7000,  1.7537,  1.4451,
#           1.4137,  1.2849,  1.7302,  1.1011,  1.6433,  1.7018,  1.6603,
#           1.7118]], device='cuda:0')
# None tensor([ 0.0388, -0.0025, -0.0903, -0.1084], device='cuda:0')
#
# Critic:
#
# None tensor([[-5.0337e-02, -3.5694e-02,  7.9814e-02,  ...,  3.9949e-02,
#           3.1087e-02, -2.1986e-02],
#         [-6.5563e-02, -6.4309e-02, -5.0068e-02,  ...,  2.4108e-02,
#          -3.4499e-02, -2.2267e-02],
#         [-4.3260e-02, -6.4825e-02, -2.7421e-02,  ...,  8.0380e-02,
#          -1.0793e-02,  4.5701e-02],
#         ...,
#         [ 5.9749e-02,  4.5869e-02, -2.7333e-02,  ..., -4.4328e-02,
#          -7.2879e-02, -6.8075e-03],
#         [-7.3861e-02,  4.1601e-02, -1.8686e-02,  ..., -2.5556e-02,
#           7.0320e-03, -4.7848e-02],
#         [-4.4751e-02, -1.4412e-02, -1.1223e-02,  ...,  2.2938e-02,
#           2.4609e-02,  3.5564e-02]], device='cuda:0')
# None tensor([-0.0895, -0.0382, -0.1260, -0.0197, -0.1698, -0.1383,  0.0888,
#         -0.0629, -0.0870, -0.0393, -0.1772,  0.1496, -0.0063, -0.0343,
#         -0.0739,  0.0725, -0.1397,  0.0730, -0.1208, -0.0787, -0.1245,
#         -0.1072, -0.0199, -0.1438, -0.1242, -0.1771,  0.0645, -0.1360,
#         -0.0281, -0.0353, -0.1304, -0.1310, -0.0350,  0.1217, -0.0426,
#          0.1368,  0.0796, -0.1275,  0.0469, -0.1637, -0.0987,  0.1628,
#          0.1687, -0.1123,  0.0076, -0.1774, -0.1007,  0.0450, -0.1714,
#         -0.0463, -0.0791, -0.1317,  0.0870, -0.0998,  0.1431,  0.0288,
#          0.0536, -0.1278,  0.0057,  0.1353, -0.1016, -0.0615, -0.0783,
#         -0.0296,  0.1108,  0.0768, -0.0477,  0.1118, -0.1535, -0.0478,
#         -0.0262, -0.0269, -0.0044,  0.0397,  0.0533, -0.1473,  0.0632,
#          0.0211,  0.1118, -0.0156, -0.1702,  0.0436, -0.0811, -0.1203,
#         -0.0400,  0.1441, -0.1342, -0.0852, -0.1766, -0.0371,  0.0408,
#          0.0777, -0.0561,  0.1273,  0.0778,  0.0993, -0.0945,  0.1143,
#         -0.0616,  0.1138,  0.1007, -0.1526,  0.0218,  0.0201, -0.0181,
#          0.0996,  0.0622, -0.1830,  0.0995,  0.0408,  0.0445,  0.0183,
#          0.0012, -0.0971,  0.0485, -0.0022,  0.0738, -0.0426,  0.1104,
#         -0.0204, -0.0239, -0.0629,  0.1500,  0.0109, -0.0845, -0.0886,
#          0.1672, -0.1641], device='cuda:0')
# None tensor([[-4.0692e-03,  9.1768e-02, -1.0289e-01,  ..., -5.6493e-02,
#           1.3443e-02,  1.2638e-02],
#         [ 1.8114e-02, -4.6792e-02, -8.8387e-02,  ...,  1.0540e-01,
#          -3.6804e-02, -7.8224e-02],
#         [-4.9276e-02, -1.0183e-01, -3.5533e-02,  ..., -6.2173e-02,
#          -8.2219e-02, -7.4947e-02],
#         ...,
#         [-1.1013e-01, -7.8223e-02,  1.1263e-01,  ..., -4.5558e-02,
#           1.0824e-01, -7.4288e-02],
#         [-7.8266e-02, -8.4536e-02, -9.0471e-02,  ...,  5.0654e-02,
#          -4.4972e-02, -1.8103e-02],
#         [-9.7244e-02, -3.0505e-02, -4.3827e-02,  ..., -1.2424e-01,
#          -9.0587e-02,  2.9222e-02]], device='cuda:0')
# None tensor(1.00000e-02 *
#        [-7.2946,  6.3280, -0.9575,  3.3975,  5.0799, -0.1153,  3.1747,
#         -3.5491, -8.1123, -3.2299, -4.3571, -4.5646, -9.7538, -8.4045,
#          6.0053, -1.8493, -1.5996, -0.3202,  4.7760, -9.3240,  5.0941,
#          3.8426, -6.2211,  7.9675,  3.5838,  0.1948,  5.0944,  5.6206,
#          6.4726,  2.4043, -4.9651, -9.4697, -2.7545,  2.2848, -1.5620,
#         -1.6345, -4.3892, -2.9723, -2.9126,  7.2852,  0.6299, -9.0621,
#         -0.3679, -5.4175,  2.0855, -6.6379, -3.4568, -5.6223, -4.9166,
#          6.3567,  7.3209, -3.6122,  5.2582,  2.4032, -1.5941, -6.2622,
#          5.4450, -6.9706,  0.7378,  1.0662, -4.5234,  6.6921, -0.6979,
#         -2.4290], device='cuda:0')
# None tensor(1.00000e-02 *
#        [[-0.1171, -0.1135,  0.4272,  0.0798,  0.6195,  0.3318, -0.2897,
#           0.0299, -0.1725,  0.4000,  0.0300,  0.4844, -0.0007, -0.1586,
#          -0.1652, -0.2512, -0.0993, -0.1235,  0.1138,  0.0938,  0.5316,
#          -0.2447,  0.1108,  0.1996,  0.2937,  0.4410,  0.0982,  0.9527,
#          -0.0200,  0.3870,  0.0602,  0.4665,  1.0379, -0.1001, -0.2429,
#           0.4327,  0.3295, -0.1767,  0.2784, -0.0832, -0.0816, -0.1193,
#          -0.0484,  0.0194,  1.0162,  0.0035, -0.0718,  0.3442,  0.0076,
#          -0.0449,  0.5940,  0.1472, -0.2150,  0.4597,  0.2073, -0.2566,
#           0.1219,  0.0451,  0.3049, -0.0266,  0.0112, -0.2383, -0.0907,
#          -0.0100]], device='cuda:0')
# None tensor(1.00000e-02 *
#        [ 7.8300], device='cuda:0')

# %% [markdown]
# ### 3. Train the Agent with DDPG

# %%
def ddpg(n_episodes=1000, max_t=300, print_every=100):
    scores_deque = deque(maxlen=print_every)
    scores = []
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]     # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        score = 0
        for t in range(1, max_t):
            pdb.set_trace()
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations 
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished 
            agent.step(states, actions, rewards, next_states, dones)
            states = next_states
            score += np.mean(rewards)
            if max(dones):
                break 
                
        scores_deque.append(score)
        scores.append(score)
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
        torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            
    return scores

scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# > <ipython-input-6-1144a5fd2c85>(10)ddpg()
# -> actions = agent.act(states)
# (Pdb) n
# > <ipython-input-6-1144a5fd2c85>(11)ddpg()
# -> env_info = env.step(actions)[brain_name]
# (Pdb) actions
# [array([-1.        ,  1.        , -0.929157  ,  0.82800275], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.79032415], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.80475575], dtype=float32), array([-1.       ,  1.       , -1.       ,  0.9034385], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32), array([-1.       ,  1.       , -0.9346798,  1.       ], dtype=float32), array([-1.       ,  1.       , -0.9727656,  1.       ], dtype=float32), array([-1.        ,  1.        , -0.91251266,  0.9529667 ], dtype=float32), array([-0.96181315,  1.        , -0.9973165 ,  1.        ], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.97721547], dtype=float32), array([-1.       ,  1.       , -1.       ,  0.9363132], dtype=float32), array([-0.9966017,  1.       , -1.       ,  0.9064387], dtype=float32), array([-0.95749164,  1.        , -0.9620142 ,  0.9882752 ], dtype=float32), array([-1.        ,  1.        , -0.94292814,  1.        ], dtype=float32), array([-1.        ,  1.        , -0.89732563,  0.96190476], dtype=float32), array([-1.        ,  1.        , -0.9167113 ,  0.93097574], dtype=float32), array([-1.       ,  1.       , -0.9188491,  0.9650019], dtype=float32), array([-1.      ,  1.      , -0.936074,  1.      ], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32)]
# (Pdb) q
# --KeyboardInterrupt--
# (Pdb)
# [array([-1.        ,  1.        , -0.929157  ,  0.82800275], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.79032415], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.80475575], dtype=float32), array([-1.       ,  1.       , -1.       ,  0.9034385], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32), array([-1.       ,  1.       , -0.9346798,  1.       ], dtype=float32), array([-1.       ,  1.       , -0.9727656,  1.       ], dtype=float32), array([-1.        ,  1.        , -0.91251266,  0.9529667 ], dtype=float32), array([-0.96181315,  1.        , -0.9973165 ,  1.        ], dtype=float32), array([-1.        ,  1.        , -1.        ,  0.97721547], dtype=float32), array([-1.       ,  1.       , -1.       ,  0.9363132], dtype=float32), array([-0.9966017,  1.       , -1.       ,  0.9064387], dtype=float32), array([-0.95749164,  1.        , -0.9620142 ,  0.9882752 ], dtype=float32), array([-1.        ,  1.        , -0.94292814,  1.        ], dtype=float32), array([-1.        ,  1.        , -0.89732563,  0.96190476], dtype=float32), array([-1.        ,  1.        , -0.9167113 ,  0.93097574], dtype=float32), array([-1.       ,  1.       , -0.9188491,  0.9650019], dtype=float32), array([-1.      ,  1.      , -0.936074,  1.      ], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32), array([-1.,  1., -1.,  1.], dtype=float32)]
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-1144a5fd2c85> in <module>
#      29     return scores
#      30
# ---> 31 scores = ddpg()
#      32
#      33 fig = plt.figure()
#
# <ipython-input-6-1144a5fd2c85> in ddpg(n_episodes, max_t, print_every)
#       9             pdb.set_trace()
#      10             actions = agent.act(states)
# ---> 11             env_info = env.step(actions)[brain_name]
#      12             next_states = env_info.vector_observations
#      13             rewards = env_info.rewards                         # get reward (for each agent)
#
# <ipython-input-6-1144a5fd2c85> in ddpg(n_episodes, max_t, print_every)
#       9             pdb.set_trace()
#      10             actions = agent.act(states)
# ---> 11             env_info = env.step(actions)[brain_name]
#      12             next_states = env_info.vector_observations
#      13             rewards = env_info.rewards                         # get reward (for each agent)
#
# c:\anaconda3\envs\p1\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# c:\anaconda3\envs\p1\lib\bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:

# %% [markdown]
# ### 4. Watch a Smart Agent!

# %%
agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

state = env.reset()
for t in range(200):
    action = agent.act(state, add_noise=False)
    env.render()
    state, reward, done, _ = env.step(action)
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-06c5ca0fc95f> in <module>
#       4 state = env.reset()
#       5 for t in range(200):
# ----> 6     action = agent.act(state, add_noise=False)
#       7     env.render()
#       8     state, reward, done, _ = env.step(action)
#
# ~\Dropbox (The University of Manchester)\D2019\University\Udacity\P2_Reacher_Submission\Udacity\MultiAgent\ddpg_agent.py in act(self, states, add_noise)
#      75         #pdb.set_trace()
#      76         for state in states:
# ---> 77             state = torch.from_numpy(state).float().to(device)
#      78             self.actor_local.eval()
#      79             with torch.no_grad():
#
# TypeError: expected np.ndarray (got str)

# %% [markdown]
# ### 6. Explore
#
# In this exercise, we have provided a sample DDPG agent and demonstrated how to use it to solve an OpenAI Gym environment.  To continue your learning, you are encouraged to complete any (or all!) of the following tasks:
# - Amend the various hyperparameters and network architecture to see if you can get your agent to solve the environment faster than this benchmark implementation.  Once you build intuition for the hyperparameters that work well with this environment, try solving a different OpenAI Gym task!
# - Write your own DDPG implementation.  Use this code as reference only when needed -- try as much as you can to write your own algorithm from scratch.
# - You may also like to implement prioritized experience replay, to see if it speeds learning.
# - The current implementation adds Ornsetein-Uhlenbeck noise to the action space.  However, it has [been shown](https://blog.openai.com/better-exploration-with-parameter-noise/) that adding noise to the parameters of the neural network policy can improve performance.  Make this change to the code, to verify it for yourself!
# - Write a blog post explaining the intuition behind the DDPG algorithm and demonstrating how to use it to solve an RL environment of your choosing.
